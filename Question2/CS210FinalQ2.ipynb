# %%
import matplotlib.pyplot as plt

u_new = 0
u_used1 = 0
u_used2 = 0
u_used3 = 0
u_used4 = 0
u_used5 = 0
u_used6 = 0
u_used7 = 0
u_used8 = 0
u_dead = 0

u_new_list = []
u_used1_list = []
u_used2_list = []
u_used3_list = []
u_used4_list = []
u_used5_list = []
u_used6_list = []
u_used7_list = []
u_used8_list = []
u_dead_list = []


for i in range(80):
    u_new = 100+0.9*1*u_used1
    u_used1 = max(90+0.9*(0.9*u_used1+0.1*u_used2), -250+0.9*1*u_new)
    u_used2 = max(80+0.9*(0.8*u_used2+0.2*u_used3), -250+0.9*1*u_new)
    u_used3 = max(70+0.9*(0.7*u_used3+0.3*u_used4), -250+0.9*1*u_new)
    u_used4 = max(60+0.9*(0.6*u_used4+0.4*u_used5), -250+0.9*1*u_new)
    u_used5 = max(50+0.9*(0.5*u_used5+0.5*u_used6), -250+0.9*1*u_new)
    u_used6 = max(40+0.9*(0.4*u_used6+0.6*u_used7), -250+0.9*1*u_new)
    u_used7 = max(30+0.9*(0.3*u_used7+0.7*u_used8), -250+0.9*1*u_new)
    u_used8 = max(20+0.9*(0.2*u_used8+0.8*u_dead), -250+0.9*1*u_new)
    u_dead = -250+0.9*1*u_new
    u_new_list.append(u_new)
    u_used1_list.append(u_used1)
    u_used2_list.append(u_used2)
    u_used3_list.append(u_used3)
    u_used4_list.append(u_used4)
    u_used5_list.append(u_used5)
    u_used6_list.append(u_used6)
    u_used7_list.append(u_used7)
    u_used8_list.append(u_used8)
    u_dead_list.append(u_dead)
print("u_new: ", u_new)
print("u_used1: ", u_used1)
print("u_used2: " ,u_used2)
print("u_used3: " ,u_used3)
print("u_used4: " ,u_used4)
print("u_used5: " ,u_used5)
print("u_used6: " ,u_used6)
print("u_used7: " ,u_used7)
print("u_used8: " ,u_used8)
print("u_dead: " ,u_dead)

plt.plot(u_new_list)
plt.plot(u_used1_list)
plt.plot(u_used2_list)
plt.plot(u_used3_list)
plt.plot(u_used4_list)
plt.plot(u_used5_list)
plt.plot(u_used6_list)
plt.plot(u_used7_list)
plt.plot(u_used8_list)
plt.plot(u_dead_list)
plt.axis([0, 80, 0, 850])
plt.xlabel('Iterations')
plt.ylabel('Utility')
plt.show()
# Out:
# u_new:  800.4317215421976
# u_used1:  778.2690026514388
# u_used2:  643.1271786944175
# u_used3:  556.0305273768115
# u_used4:  502.74431291683374
# u_used5:  475.7553132243413
# u_used6:  470.38854938797783
# u_used7:  470.38854938797783
# u_used8:  470.38854938797783
# u_dead:  470.38854938797783

# %%
0.9*(0.5*u_used1+0.5*u_used2)+250-0.9*u_new
# Out:
# 169.23973221765755

# %%
pi_new = 'use'
if 90+0.9*(0.9*u_used1+0.1*u_used2) > -250+0.9*1*u_new:
    pi_used1 = 'use'
else:
    pi_used1 = 'repalce'
if 80+0.9*(0.8*u_used2+0.2*u_used3) > -250+0.9*1*u_new:
    pi_used2 = 'use'
else:
    pi_used2 = 'repalce'
if 70+0.9*(0.7*u_used3+0.3*u_used4) > -250+0.9*1*u_new:
    pi_used3 = 'use'
else:
    pi_used3 = 'repalce'
if 60+0.9*(0.6*u_used4+0.4*u_used5) > -250+0.9*1*u_new:
    pi_used4 = 'use'
else:
    pi_used4 = 'repalce'
if 50+0.9*(0.5*u_used5+0.5*u_used6) > -250+0.9*1*u_new:
    pi_used5 = 'use'
else:
    pi_used5 = 'repalce'
if 40+0.9*(0.4*u_used6+0.6*u_used7) > -250+0.9*1*u_new:
    pi_used6 = 'use'
else:
    pi_used6 = 'repalce'
if 30+0.9*(0.3*u_used7+0.7*u_used8) > -250+0.9*1*u_new:
    pi_used7 = 'use'
else:
    pi_used7 = 'repalce'
if 20+0.9*(0.2*u_used8+0.8*u_dead) > -250+0.9*1*u_new:
    pi_used8 = 'use'
else:
    pi_used8 = 'repalce'
pi_dead = 'replace'
    
print("pi_new: ", pi_new)
print("pi_used1: ", pi_used1)
print("pi_used2: " ,pi_used2)
print("pi_used3: " ,pi_used3)
print("pi_used4: " ,pi_used4)
print("pi_used5: " ,pi_used5)
print("pi_used6: " ,pi_used6)
print("pi_used7: " ,pi_used7)
print("pi_used8: " ,pi_used8)
print("pi_dead: " ,pi_dead)
# Out:
# pi_new:  use
# pi_used1:  use
# pi_used2:  use
# pi_used3:  use
# pi_used4:  use
# pi_used5:  use
# pi_used6:  repalce
# pi_used7:  repalce
# pi_used8:  repalce
# pi_dead:  replace

# %%
u_new = 0
u_used1 = 0
u_used2 = 0
u_used3 = 0
u_used4 = 0
u_used5 = 0
u_used6 = 0
u_used7 = 0
u_used8 = 0
u_dead = 0

beta_list = [0.1,0.3,0.5,0.7,0.8,0.9,0.99]

for beta in beta_list:
    for i in range(10000):
        u_new = 100+beta*1*u_used1
        u_used1 = max(90+beta*(0.9*u_used1+0.1*u_used2), -250+beta*1*u_new)
        u_used2 = max(80+beta*(0.8*u_used2+0.2*u_used3), -250+beta*1*u_new)
        u_used3 = max(70+beta*(0.7*u_used3+0.3*u_used4), -250+beta*1*u_new)
        u_used4 = max(60+beta*(0.6*u_used4+0.4*u_used5), -250+beta*1*u_new)
        u_used5 = max(50+beta*(0.5*u_used5+0.5*u_used6), -250+beta*1*u_new)
        u_used6 = max(40+beta*(0.4*u_used6+0.6*u_used7), -250+beta*1*u_new)
        u_used7 = max(30+beta*(0.3*u_used7+0.7*u_used8), -250+beta*1*u_new)
        u_used8 = max(20+beta*(0.2*u_used8+0.8*u_dead), -250+beta*1*u_new)
        u_dead = -250+beta*1*u_new
    
    print("u_new: ", u_new)
    print("u_used1: ", u_used1)
    print("u_used2: " ,u_used2)
    print("u_used3: " ,u_used3)
    print("u_used4: " ,u_used4)
    print("u_used5: " ,u_used5)
    print("u_used6: " ,u_used6)
    print("u_used7: " ,u_used7)
    print("u_used8: " ,u_used8)
    print("u_dead: " ,u_dead)
    print('')
    
    pi_new = 'use'
    if 90+beta*(0.9*u_used1+0.1*u_used2) > -250+beta*1*u_new:
        pi_used1 = 'use'
    else:
        pi_used1 = 'repalce'
    if 80+beta*(0.8*u_used2+0.2*u_used3) > -250+beta*1*u_new:
        pi_used2 = 'use'
    else:
        pi_used2 = 'repalce'
    if 70+beta*(0.7*u_used3+0.3*u_used4) > -250+beta*1*u_new:
        pi_used3 = 'use'
    else:
        pi_used3 = 'repalce'
    if 60+beta*(0.6*u_used4+0.4*u_used5) > -250+beta*1*u_new:
        pi_used4 = 'use'
    else:
        pi_used4 = 'repalce'
    if 50+beta*(0.5*u_used5+0.5*u_used6) > -250+beta*1*u_new:
        pi_used5 = 'use'
    else:
        pi_used5 = 'repalce'
    if 40+beta*(0.4*u_used6+0.6*u_used7) > -250+beta*1*u_new:
        pi_used6 = 'use'
    else:
        pi_used6 = 'repalce'
    if 30+beta*(0.3*u_used7+0.7*u_used8) > -250+beta*1*u_new:
        pi_used7 = 'use'
    else:
        pi_used7 = 'repalce'
    if 20+beta*(0.2*u_used8+0.8*u_dead) > -250+beta*1*u_new:
        pi_used8 = 'use'
    else:
        pi_used8 = 'repalce'
    pi_dead = 'replace'
    print("beta =", beta)
    print("pi_new: ", pi_new)
    print("pi_used1: ", pi_used1)
    print("pi_used2: " ,pi_used2)
    print("pi_used3: " ,pi_used3)
    print("pi_used4: " ,pi_used4)
    print("pi_used5: " ,pi_used5)
    print("pi_used6: " ,pi_used6)
    print("pi_used7: " ,pi_used7)
    print("pi_used8: " ,pi_used8)
    print("pi_dead: " ,pi_dead)
    print('')
# Out:
# u_new:  109.98751560533492
# u_used1:  99.87515605334912
# u_used2:  88.6392008547693
# u_used3:  77.4032393193877
# u_used4:  66.16708556768504
# u_used5:  54.926510840598155
# u_used6:  43.603705971364946
# u_used7:  30.99262887517251
# u_used8:  0.8978572702476306
# u_dead:  -239.0012484394665
#
# beta = 0.1
# pi_new:  use
# pi_used1:  use
# pi_used2:  use
# pi_used3:  use
# pi_used4:  use
# pi_used5:  use
# pi_used6:  use
# pi_used7:  use
# pi_used8:  use
# pi_dead:  replace
#
# u_new:  138.37952342733814
# u_used1:  127.93174475779384
# u_used2:  113.00578910631694
# u_used3:  98.07332868001464
# u_used4:  83.08810730235086
# u_used5:  67.76873323273094
# u_used6:  50.68948831880864
# u_used7:  25.593054003064477
# u_used8:  -31.95390884386346
# u_dead:  -208.48614297179856
#
# beta = 0.3
# pi_new:  use
# pi_used1:  use
# pi_used2:  use
# pi_used3:  use
# pi_used4:  use
# pi_used5:  use
# pi_used6:  use
# pi_used7:  use
# pi_used8:  use
# pi_dead:  replace
#
# ...
